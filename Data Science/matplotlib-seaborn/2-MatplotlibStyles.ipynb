# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 ** 2

# %%
plt.subplots() # bir figür bir eksen döndürür
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig, my_axes = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %% [markdown]
# Tek bir grafikte 2 veri çizdirme

# %%
my_fig, my_axes = plt.subplots()
my_axes.plot(data1, data2, color="#ffe333", alpha=0.5) # alpha transparan ypar
my_axes.plot(data2, data1, color="#000000")
plt.show()

# %%
(new_fig, new_axes) =  plt.subplots()
new_axes.plot( data1, data1 + 2, color="blue", linewidth=1.0)

new_axes.plot( data1, data1 + 3, color="yellow", linewidth=4.0)

new_axes.plot( data1, data1 + 4, color="#c85d09", linestyle="-.")
new_axes.plot( data1, data1 + 5, color="#c85d09", linestyle=":")
new_axes.plot( data1, data1 + 6, color="#c85d09", linestyle="--")


new_axes.plot( data1, data1 + 7, color="#000000" , linestyle="--", marker="o", markersize=8, markerfacecolor="red")
new_axes.plot( data1, data1 + 8, color="#000000" , linestyle="--", marker="+", markersize=10, )

# %% [markdown]
# Scatter Plot: iki numerik değişken arasındaki ilişki
# Histogram : numerik değişkenlerin dağılımına bakar

# %%
# scatter

# %%
plt.scatter(data1, data2, color="black")

# %%
# histogram

# %%
new_arr = np.random.randint(0,100,50)
new_arr
# Out:
# array([89, 40, 67, 79, 25, 14, 76, 91, 25, 97, 39, 73, 21, 49,  4, 74, 92,
#        24, 94,  3, 95, 84, 19, 34, 11, 25, 40, 14, 71, 28, 61, 92, 61, 79,
#        31, 95, 29,  1, 19, 72, 19, 43, 87, 82, 63, 69, 56, 51, 82, 57])

# %%
plt.hist(new_arr)
# Out:
# (array([3., 6., 7., 3., 3., 4., 4., 6., 6., 8.]),
#  array([ 1. , 10.6, 20.2, 29.8, 39.4, 49. , 58.6, 68.2, 77.8, 87.4, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
# boxplot

# %%
plt.boxplot(new_arr)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1661b014e90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16618d792d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1661b3c0050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1661af98810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1661af9bd90>],
#  'means': []}
